# %% [markdown]
# # Face Detection & Face Segmentation — Notebook Workspace
#
# Placeholder for exploratory notebooks (EDA, error analysis, hyperparameter sweeps).
#
# For a working demo, see `demos/quick_demo.ipynb`.
